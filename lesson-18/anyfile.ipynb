# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
plt.plot([1,2,5,4])  #by default y-axis

# %%
plt.plot([1,2,5,4],[3,2,4,1])  # axis(x,y)

# %%
plt.plot([1,1.5,2,2.5,1.5,2.5,3],[1,2,3,2,2,2,1])

# %%
plt.plot([1,4,6],[2,3,5],[4,2],[3,3])

# %%
plt.plot([1,1,1.5,1.5,1],[1,3,3,1,1])

# %%
plt.plot([1,1,1.5,1.5 ],[1,3,1,3 ])

# %%
plt.plot([3,3.5,4,4.5,3.5,4.5,5],[1,2,3,2,2,2,1])

# %%
plt.plot([1,1,1.5,1.5,1],[1,3,3,1,1],[2,2,2.5,2.5 ],[1,3,1,3 ],[3,3.5,4,4.5,3.5,4.5,5],[1,2,3,2,2,2,1])

# %%
plt.plot([2,2,1,1,3,3,4,4,4,5,6,7,6.5,5.5],[1,3,3,1,1,3,1,3,1,1,3,1,2,2])

# %% [markdown]
# ## Figure

# %%
fig=plt.figure()

# %%
ax1=fig.add_subplot(2,2,1)

# %%
ax2=fig.add_subplot(2,2,2)

# %%
fig

# %%
plt.plot(np.random.randn(50),'rD--')

# %%
ax1.hist(np.random.randn(100),bins=20, color='red')
# Out:
# (array([ 1.,  0.,  0.,  5.,  6.,  3.,  8.,  6.,  8., 14., 12., 13.,  6.,
#          3.,  2.,  6.,  1.,  3.,  1.,  2.]),
#  array([-2.46819605, -2.21795912, -1.96772219, -1.71748525, -1.46724832,
#         -1.21701139, -0.96677446, -0.71653752, -0.46630059, -0.21606366,
#          0.03417327,  0.28441021,  0.53464714,  0.78488407,  1.035121  ,
#          1.28535793,  1.53559487,  1.7858318 ,  2.03606873,  2.28630566,
#          2.5365426 ]),
#  <BarContainer object of 20 artists>)

# %%
fig

# %%
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))

# %%
fig

# %%
data=np.random.randn(30)

plt.plot(data, 'k--')

# %%
plt.plot(data,'b-',drawstyle='steps-post')

# %%
import pandas as pd

df=pd.DataFrame(np.random.randn(10,4), columns=['A','B','C','D'])

# %%
df.plot()
# Out:
# <Axes: >

# %%
df
# Out:
#           A         B         C         D
# 0 -1.285625  1.254465  0.144761 -0.196230
# 1  0.536068  0.257315  0.163631  1.028413
# 2 -0.502665 -0.479951 -1.243739 -0.242040
# 3 -1.889365  0.209003  1.067041  0.659228
# 4  0.155331 -1.053291  1.309829  0.278332
# 5 -0.406765  0.485928 -0.504174 -0.168402
# 6  0.205701 -0.113314  0.596684 -0.047993
# 7 -0.892827  1.515204  1.935681  0.847948
# 8 -0.234845  0.268241 -0.175543 -1.317369
# 9 -1.619266 -0.577890 -1.203806  1.237414

# %%
fig,axes=plt.subplots(2,1)

data=pd.Series(np.random.randn(16),index=list('abcdefghijklmnop'))
data.plot()
# Out:
# <Axes: >

# %%
data.plot.bar(ax=axes[0], color='r')
data.plot.bar(ax=axes[1], color='b')
fig

# %%
df=pd.DataFrame(np.random.randn(6,4), index=['one','two','three','four','five','six'], columns=pd.Index(['A','B','C','D'], name='Letters'))
df.plot.barh(stacked=True)
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

tips=pd.read_csv('tips.csv')

num_smokers=(tips['smoker']=='Yes').sum()
num_no_smokers=(tips['smoker']=='No').sum()

sum_bill_smoker=tips.loc[tips['smoker']=='Yes','tip'].sum()
sum_bill_no_smoker=tips.loc[tips['smoker']=='Yes','tip'].sum()

df=pd.DataFrame()
# Out:
# np.float64(279.81)
