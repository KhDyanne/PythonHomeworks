# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
with open('movie.csv','r') as f:
    data=f.readlines(1)
    print(data)
# Out:
# ['color,director_name,num_critic_for_reviews,duration,director_facebook_likes,actor_3_facebook_likes,actor_2_name,actor_1_facebook_likes,gross,genres,actor_1_name,movie_title,num_voted_users,cast_total_facebook_likes,actor_3_name,facenumber_in_poster,plot_keywords,movie_imdb_link,num_user_for_reviews,language,country,content_rating,budget,title_year,actor_2_facebook_likes,imdb_score,aspect_ratio,movie_facebook_likes\n']

# %%
movies=pd.read_csv('movie.csv')
movies.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration  \
# 0  Color      James Cameron                   723.0     178.0
# 1  Color     Gore Verbinski                   302.0     169.0
# 2  Color         Sam Mendes                   602.0     148.0
# 3  Color  Christopher Nolan                   813.0     164.0
# 4    NaN        Doug Walker                     NaN       NaN
#
#    director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                      0.0                   855.0  Joel David Moore
# 1                    563.0                  1000.0     Orlando Bloom
# 2                      0.0                   161.0      Rory Kinnear
# 3                  22000.0                 23000.0    Christian Bale
# 4                    131.0                     NaN        Rob Walker
#
#    actor_1_facebook_likes        gross                           genres  ...  \
# 0                  1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi  ...
# ...

# %%
movies.tail(4)
# Out:
#       color     director_name  num_critic_for_reviews  duration  \
# 4912  Color               NaN                    43.0      43.0
# 4913  Color  Benjamin Roberds                    13.0      76.0
# 4914  Color       Daniel Hsia                    14.0     100.0
# 4915  Color          Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes    gross                        genres  ...  \
# 4912                   841.0      NaN  Crime|Drama|Mystery|Thriller  ...
# 4913                     0.0      NaN         Drama|Horror|Thriller  ...
# ...

# %%
columns=movies.columns
columns
# Out:
# Index(['color', 'director_name', 'num_critic_for_reviews', 'duration',
#        'director_facebook_likes', 'actor_3_facebook_likes', 'actor_2_name',
#        'actor_1_facebook_likes', 'gross', 'genres', 'actor_1_name',
#        'movie_title', 'num_voted_users', 'cast_total_facebook_likes',
#        'actor_3_name', 'facenumber_in_poster', 'plot_keywords',
#        'movie_imdb_link', 'num_user_for_reviews', 'language', 'country',
#        'content_rating', 'budget', 'title_year', 'actor_2_facebook_likes',
#        'imdb_score', 'aspect_ratio', 'movie_facebook_likes'],
#       dtype='object')

# %%
index=movies.index
index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
values=movies.values
values
# Out:
# array([['Color', 'James Cameron', 723.0, ..., 7.9, 1.78, 33000],
#        ['Color', 'Gore Verbinski', 302.0, ..., 7.1, 2.35, 0],
#        ['Color', 'Sam Mendes', 602.0, ..., 6.8, 2.35, 85000],
#        ...,
#        ['Color', 'Benjamin Roberds', 13.0, ..., 6.3, nan, 16],
#        ['Color', 'Daniel Hsia', 14.0, ..., 6.3, 2.35, 660],
#        ['Color', 'Jon Gunn', 43.0, ..., 6.6, 1.85, 456]],
#       shape=(4916, 28), dtype=object)

# %%
print(type(columns))
print(type(index))
print(type(values))
# Out:
# <class 'pandas.core.indexes.base.Index'>
# <class 'pandas.core.indexes.range.RangeIndex'>
# <class 'numpy.ndarray'>

# %%
#DataFrame
#Series

# %%
movies.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# ...

# %%
movies.dtypes.value_counts()
# Out:
# float64    13
# object     12
# int64       3
# Name: count, dtype: int64

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4916 entries, 0 to 4915
# Data columns (total 28 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   color                      4897 non-null   object
#  1   director_name              4814 non-null   object
#  2   num_critic_for_reviews     4867 non-null   float64
#  3   duration                   4901 non-null   float64
#  4   director_facebook_likes    4814 non-null   float64
#  5   actor_3_facebook_likes     4893 non-null   float64
#  6   actor_2_name               4903 non-null   object
#  7   actor_1_facebook_likes     4909 non-null   float64
#  8   gross                      4054 non-null   float64
#  9   genres                     4916 non-null   object
#  10  actor_1_name               4909 non-null   object
#  11  movie_title                4916 non-null   object
#  12  num_voted_users            4916 non-null   int64
# ...

# %%
import numpy as np

# %%
pd.Series(['Apple',None,'Pear', np.nan])
# Out:
# 0    Apple
# 1     None
# 2     Pear
# 3      NaN
# dtype: object

# %%
movies['director_name']
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                  NaN
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
movies[['director_name','duration']]
# Out:
#           director_name  duration
# 0         James Cameron     178.0
# 1        Gore Verbinski     169.0
# 2            Sam Mendes     148.0
# 3     Christopher Nolan     164.0
# 4           Doug Walker       NaN
# ...                 ...       ...
# 4911        Scott Smith      87.0
# 4912                NaN      43.0
# 4913   Benjamin Roberds      76.0
# 4914        Daniel Hsia     100.0
# 4915           Jon Gunn      90.0
#
# [4916 rows x 2 columns]

# %%
movies['director_name'].index
# Out:
# RangeIndex(start=0, stop=4916, step=1)

# %%
movies['director_name'].dtype
# Out:
# dtype('O')

# %%
type(movies['director_name'])
# Out:
# pandas.core.series.Series

# %%
movies['director_name'].size
# Out:
# 4916

# %%
director=movies['director_name']

# %%
director.name
# Out:
# 'director_name'

# %%
director.sample(10)
# Out:
# 2092      Camille Delamarre
# 4456            Sean Durkin
# 3216            Anurag Basu
# 3459         Spencer Susser
# 2147    Julie Anne Robinson
# 3367        Bruce Beresford
# 4154              Dan Perri
# 3960              Max Mayer
# 1702            Steve Boyum
# 100               Rob Cohen
# Name: director_name, dtype: object

# %%
fb_likes=movies['actor_1_facebook_likes']
fb_likes.value_counts()
# Out:
# actor_1_facebook_likes
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 375.0        1
# 318.0        1
# 630.0        1
# 10.0         1
# 291.0        1
# Name: count, Length: 877, dtype: int64

# %%
print(fb_likes.max())
# Out:
# 640000.0

# %%
fb_likes.value_counts()
# Out:
# actor_1_facebook_likes
# 1000.0     436
# 11000.0    206
# 2000.0     189
# 3000.0     150
# 12000.0    131
#           ...
# 375.0        1
# 318.0        1
# 630.0        1
# 10.0         1
# 291.0        1
# Name: count, Length: 877, dtype: int64

# %%
max_like_person=movies['actor_1_name'].loc[movies['actor_1_facebook_likes'].idxmax()]
max_like_person
# Out:
# 'Darcy Donavan'

# %%
fb_likes.describe()
# Out:
# count      4909.000000
# mean       6494.488491
# std       15106.986884
# min           0.000000
# 25%         607.000000
# 50%         982.000000
# 75%       11000.000000
# max      640000.000000
# Name: actor_1_facebook_likes, dtype: float64

# %%
director.isna()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4911    False
# 4912     True
# 4913    False
# 4914    False
# 4915    False
# Name: director_name, Length: 4916, dtype: bool

# %%
director.fillna(0)
# Out:
# 0           James Cameron
# 1          Gore Verbinski
# 2              Sam Mendes
# 3       Christopher Nolan
# 4             Doug Walker
#               ...
# 4911          Scott Smith
# 4912                    0
# 4913     Benjamin Roberds
# 4914          Daniel Hsia
# 4915             Jon Gunn
# Name: director_name, Length: 4916, dtype: object

# %%
fb_likes.fillna(0).count()
# Out:
# np.int64(4916)

# %%
fb_likes.dropna()
# Out:
# 0        1000.0
# 1       40000.0
# 2       11000.0
# 3       27000.0
# 4         131.0
#          ...
# 4911      637.0
# 4912      841.0
# 4913        0.0
# 4914      946.0
# 4915       86.0
# Name: actor_1_facebook_likes, Length: 4909, dtype: float64

# %%
imdb_score=movies['imdb_score']
imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 4911    7.7
# 4912    7.5
# 4913    6.3
# 4914    6.3
# 4915    6.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
imdb_score+1
# Out:
# 0       8.9
# 1       8.1
# 2       7.8
# 3       9.5
# 4       8.1
#        ...
# 4911    8.7
# 4912    8.5
# 4913    7.3
# 4914    7.3
# 4915    7.6
# Name: imdb_score, Length: 4916, dtype: float64

# %%
money=pd.Series([100,20,None])
money
# Out:
# 0    100.0
# 1     20.0
# 2      NaN
# dtype: float64

# %%
money-15
# Out:
# 0    85.0
# 1     5.0
# 2     NaN
# dtype: float64

# %%
money.sub(15,fill_value=0)
# Out:
# 0    85.0
# 1     5.0
# 2   -15.0
# dtype: float64

# %%
money.fillna(0)-15
# Out:
# 0    85.0
# 1     5.0
# 2   -15.0
# dtype: float64

# %%
secondmoney=pd.Series([50,10,4,30])
secondmoney
# Out:
# 0    50
# 1    10
# 2     4
# 3    30
# dtype: int64

# %%
money+secondmoney
# Out:
# 0    150.0
# 1     30.0
# 2      NaN
# 3      NaN
# dtype: float64

# %%
fb_likes.fillna(0).astype(int)
# Out:
# 0        1000
# 1       40000
# 2       11000
# 3       27000
# 4         131
#         ...
# 4911      637
# 4912      841
# 4913        0
# 4914      946
# 4915       86
# Name: actor_1_facebook_likes, Length: 4916, dtype: int64

# %%
movies.rename(columns={"director_name":"director","num_critic_for_reviews":"critic_reviews"})
# Out:
#       color           director  critic_reviews  duration  \
# 0     Color      James Cameron           723.0     178.0
# 1     Color     Gore Verbinski           302.0     169.0
# 2     Color         Sam Mendes           602.0     148.0
# 3     Color  Christopher Nolan           813.0     164.0
# 4       NaN        Doug Walker             NaN       NaN
# ...     ...                ...             ...       ...
# 4911  Color        Scott Smith             1.0      87.0
# 4912  Color                NaN            43.0      43.0
# 4913  Color   Benjamin Roberds            13.0      76.0
# 4914  Color        Daniel Hsia            14.0     100.0
# 4915  Color           Jon Gunn            43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# ...

# %%
movies['viewed']=0

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.drop(columns='viewed', inplace=True)

# %%
movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
fname=['McAtee','Fede', 'Richard', 'Weah']
lname=['Freddie','Valve', 'Stark', 'Timoty']
birth=[2005,1996,1985, np.nan]

people=pd.DataFrame({"FirstName":fname, "LastName":lname, "BirthDate":birth})
people
# Out:
#   FirstName LastName  BirthDate
# 0    McAtee  Freddie     2005.0
# 1      Fede    Valve     1996.0
# 2   Richard    Stark     1985.0
# 3      Weah   Timoty        NaN

# %%
type(people['FirstName'])
# Out:
# pandas.core.series.Series

# %%
type(people[['FirstName']])
# Out:
# pandas.core.frame.DataFrame

# %%
movies[movies['director_name']=='James Cameron']
# Out:
#       color  director_name  num_critic_for_reviews  duration  \
# 0     Color  James Cameron                   723.0     178.0
# 26    Color  James Cameron                   315.0     194.0
# 285   Color  James Cameron                   210.0     153.0
# 288   Color  James Cameron                    94.0     141.0
# 599   Color  James Cameron                    82.0     171.0
# 2455  Color  James Cameron                   250.0     154.0
# 3508  Color  James Cameron                   204.0     107.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         0.0                   855.0   Joel David Moore
# 26                        0.0                   794.0       Kate Winslet
# 285                       0.0                   539.0  Jenette Goldstein
# 288                       0.0                   618.0        Tia Carrere
# 599                       0.0                   638.0         Todd Graff
# ...

# %%
a=movies[movies.director_facebook_likes==movies.director_facebook_likes.max()].director_name
b=str("".join(a))

# %%
movies[movies.director_name==a]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[93], line 1
# ----> 1 movies[movies.director_name==a]
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File c:\Program Files\Python311\Lib\site-packages\pandas\core\series.py:6114, in Series._cmp_method(self, other, op)
#    6111 res_name = ops.get_op_result_name(self, other)
#    6113 if isinstance(other, Series) and not self._indexed_same(other):
# ...

# %%
weather_data=pd.read_csv('weather_data.csv')
weather_data
# Out:
#          day  temp condition
# 0     Monday     8     Sunny
# 1    Tuesday    11      Rain
# 2  Wednesday    12      Rain
# 3   Thursday    11    Cloudy
# 4     Friday    19     Sunny
# 5   Saturday    17     Sunny
# 6     Sunday    20     Sunny

# %%
avgTemp=weather_data['temp'].mean()
maxTemp=weather_data['temp'].max()
print(avgTemp)
print(maxTemp)
# Out:
# 14.0
# 20

# %%
print(weather_data[weather_data['day']=='Monday'].condition)
# Out:
# 0    Sunny
# Name: condition, dtype: object

# %%
print(weather_data[weather_data['day']=='Friday']['temp']*1.8+32)
# Out:
# 4    66.2
# Name: temp, dtype: float64
